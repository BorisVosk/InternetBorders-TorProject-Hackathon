# %%
import pandas as pd
import numpy as np

# %%
rb_2022_df = pd.read_csv('datasets/ukr_rus_ir_all_bridge_relay_2011-2022.csv')

# %%
rb_2021_df = pd.read_csv('datasets/ukr_rus_ir_all_bridge_relay_2020-2021.csv')

# %%
rb_2021_2022_df = pd.concat([rb_2021_df, rb_2022_df]).reset_index().drop(columns=['index'])
rb_2021_2022_df
# Out:
#            date  users_bridge_ukr  users_relay_ukr  users_br_perc_ukr  \
# 0    2020-12-27               635            49319           1.271169
# 1    2020-12-28               642            50568           1.253661
# 2    2020-12-29               689            49571           1.370871
# 3    2020-12-30               701            48786           1.416534
# 4    2020-12-31               624            45661           1.348169
# ..          ...               ...              ...                ...
# 294  2022-05-21               959            37308           2.506076
# 295  2022-05-22               936            36490           2.500935
# 296  2022-05-23              1041            37653           2.690340
# 297  2022-05-24               999            35871           2.709520
# 298  2022-05-25              1020            38280           2.595420
#
#      users_bridge_rus  users_relay_rus  users_br_perc_rus  users_bridge  \
# ...

# %%
rb_2021_2022_df.date = pd.to_datetime(rb_2021_2022_df.date, format='%Y-%m-%d')

# %%
rb_2021_2022_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               299 non-null    datetime64[ns]
#  1   users_bridge_ukr   299 non-null    int64
#  2   users_relay_ukr    299 non-null    int64
#  3   users_br_perc_ukr  299 non-null    float64
#  4   users_bridge_rus   299 non-null    int64
#  5   users_relay_rus    299 non-null    int64
#  6   users_br_perc_rus  299 non-null    float64
#  7   users_bridge       299 non-null    int64
#  8   users_relay        299 non-null    int64
#  9   users_br_perc      299 non-null    float64
#  10  users_bridge_ir    299 non-null    int64
#  11  users_relay_ir     299 non-null    int64
#  12  users_br_perc_ir   299 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(8)
# memory usage: 30.5 KB

# %%
rb_2021_2022_df['year'] = rb_2021_2022_df['date'].dt.year
rb_2021_2022_df['month'] = rb_2021_2022_df['date'].dt.month

# %%
year_month_grouped = rb_2021_2022_df.groupby(['year', 'month'], as_index=False).agg('mean')
year_month_grouped
# Out:
#     year  month  users_bridge_ukr  users_relay_ukr  users_br_perc_ukr  \
# 0   2020     12        658.200000     48781.000000           1.332081
# 1   2021      1        660.964286     56268.142857           1.187337
# 2   2021      2        672.892857     54638.678571           1.218856
# 3   2021      3        723.129032     52273.741935           1.370171
# 4   2021      4        724.200000     48291.933333           1.481134
# 5   2021      5        660.142857     43979.964286           1.479399
# 6   2021     12        661.000000     40550.800000           1.605414
# 7   2022      1        696.066667     39303.800000           1.744593
# 8   2022      2        765.607143     57138.000000           1.473052
# 9   2022      3        914.709677     56912.225806           1.661516
# 10  2022      4        837.100000     38827.900000           2.112526
# 11  2022      5        977.280000     37121.000000           2.569608
#
# ...

# %%
year_month_grouped.to_csv('relay_bridge_2020-2022_group_year_month.csv', index=False)
